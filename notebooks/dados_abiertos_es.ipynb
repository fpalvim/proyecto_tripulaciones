# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from pprint import pprint
from datetime import datetime
from IPython.display import HTML, display
import folium
import json
import re
import random
import sqlite3

# %%
# descargando los datos de Agenda de actividades y eventos de la API del Portal de datos abiertos del Ayuntamiento de Madrid

url = "https://datos.gob.es/apidata/catalog/"

try:
    response = requests.get(url)
    response.raise_for_status()
    raw_text = response.text
    cleaned_text = re.sub(r"\\(?![nrtbf\"\\/])", "", raw_text)
    data = json.loads(cleaned_text)

    if isinstance(data, dict):
        print(f"Top-level dictionary keys: {data.keys()}")
        if '@graph' in data and isinstance(data['@graph'], list):
            df = pd.DataFrame(data['@graph'])
            print(df.head())
        else:
            print("The list of events was not found within the '@graph' key.")
    else:
        print("Parsed JSON is not a dictionary as expected.")

except requests.exceptions.RequestException as e:
    print(f"Error fetching data: {e}")
except json.JSONDecodeError as e:
    print(f"Error decoding JSON: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error fetching data: 403 Client Error: Forbidden for url: https://datos.gob.es/apidata/catalog/

# %%
import requests
import json

url = "http://datos.gob.es/apidata/catalog/dataset"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

try:
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    data = response.json()
    print(json.dumps(data, indent=4))
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
except json.JSONDecodeError as e:
    print(f"Error decoding JSON: {e}")
# Out:
# {
#     "format": "linked-data-api",
#     "version": "0.2",
#     "result": {
#         "_about": "http://datos.gob.es/apidata/catalog/dataset.json",
#         "definition": "http://datos.gob.es/apidata/catalog/meta/dataset.json",
#         "extendedMetadataVersion": "http://datos.gob.es/apidata/catalog/dataset.json?_metadata=all",
#         "first": "http://datos.gob.es/apidata/catalog/dataset.json?_page=0",
#         "hasPart": "http://datos.gob.es/apidata/catalog/dataset.json",
#         "isPartOf": "http://datos.gob.es/apidata/catalog/dataset.json",
#         "items": [
#             {
#                 "_about": "https://datos.gob.es/catalogo/a05003423-clasificacion-de-establecimientos-de-restauracion-istac-cl_cnae_2009_restauracion",
#                 "description": [
#                     {
#                         "_value": "Clasificaci\u00f3n que recoge los diferentes tipos de establecimientos de restauraci\u00f3n. Esta basada en la CNAE 2009 y recoge aquellas actividades relacionadas con la prestaci\u00f3n de servicios de restauraci\u00f3n en las Islas Canarias. Adem\u00e1s, recoge aquellos establecimientos de restauraci\u00f3n encontrados en los decretos DECRETO 90/2010, de 22 de julio, por el que se regula la actividad tur\u00edstica de restauraci\u00f3n y los establecimientos donde se desarrolla y DECRETO 83/2013, de 1 de agosto, por el que se regulan la actividad de comercializaci\u00f3n temporal de vino de cosecha propia y los establecimientos donde se desarrolla, que no poseen una clasificaci\u00f3n espec\u00edfica en la CNAE 2009 y que son necesarios para satisfacer las necesidades del ISTAC.",
#                         "_lang": "es"
#                     }
#                 ],
#                 "distribution": [
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-clasificacion-de-establecimientos-de-restauracion-istac-cl_cnae_2009_restauracion/resource/034a07fc-0eac-44c6-9ca9-8cf3b302bb6b",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/structural-resources/v1.0/codelists/ISTAC/CL_CNAE_2009_RESTAURACION/01.000/codes.json?fields=+description",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-clasificacion-de-establecimientos-de-restauracion-istac-cl_cnae_2009_restauracion/resource/034a07fc-0eac-44c6-9ca9-8cf3b302bb6b/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/json"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Clasificaci\u00f3n. ISTAC:CL_CNAE_2009_RESTAURACION (JSON)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-clasificacion-de-establecimientos-de-restauracion-istac-cl_cnae_2009_restauracion/resource/1df19889-8e92-4019-b9d3-75936bea2ccb",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/structural-resources/v1.0/codelists/ISTAC/CL_CNAE_2009_RESTAURACION/01.000/codes.csv?fields=+description",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-clasificacion-de-establecimientos-de-restauracion-istac-cl_cnae_2009_restauracion/resource/1df19889-8e92-4019-b9d3-75936bea2ccb/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "text/csv"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Clasificaci\u00f3n. ISTAC:CL_CNAE_2009_RESTAURACION (CSV)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-clasificacion-de-establecimientos-de-restauracion-istac-cl_cnae_2009_restauracion/resource/453d7068-7db9-4335-8890-03a927a6bfff",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/structural-resources/v1.0/codelists/ISTAC/CL_CNAE_2009_RESTAURACION/01.000/codes.xlsx?fields=+description",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-clasificacion-de-establecimientos-de-restauracion-istac-cl_cnae_2009_restauracion/resource/453d7068-7db9-4335-8890-03a927a6bfff/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Clasificaci\u00f3n. ISTAC:CL_CNAE_2009_RESTAURACION (XLSX)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-clasificacion-de-establecimientos-de-restauracion-istac-cl_cnae_2009_restauracion/resource/ab4b1a21-0d1e-43d4-9bb6-e5928dfe971e",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/structural-resources/v1.0/codelists/ISTAC/CL_CNAE_2009_RESTAURACION/01.000/codes.xml?fields=+description",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-clasificacion-de-establecimientos-de-restauracion-istac-cl_cnae_2009_restauracion/resource/ab4b1a21-0d1e-43d4-9bb6-e5928dfe971e/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/xml"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Clasificaci\u00f3n. ISTAC:CL_CNAE_2009_RESTAURACION (XML)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-clasificacion-de-establecimientos-de-restauracion-istac-cl_cnae_2009_restauracion/resource/cde78c62-cf68-438e-8559-6841a08b4d91",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/structural-resources/v1.0/codelists/ISTAC/CL_CNAE_2009_RESTAURACION/01.000/codes.tsv?fields=+description",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-clasificacion-de-establecimientos-de-restauracion-istac-cl_cnae_2009_restauracion/resource/cde78c62-cf68-438e-8559-6841a08b4d91/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "text/tab-separated-values"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Clasificaci\u00f3n. ISTAC:CL_CNAE_2009_RESTAURACION (TSV)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     }
#                 ],
#                 "identifier": "https://datos.canarias.es/catalogos/estadisticas/dataset/urn-sdmx-org-sdmx-infomodel-codelist-codelist-istac-cl_cnae_2009_restauracion",
#                 "issued": "mi\u00e9, 06 mar 2024 06:43:25 GMT+0000",
#                 "keyword": [
#                     {
#                         "_value": "Clasificaci\u00f3n",
#                         "_lang": "es"
#                     }
#                 ],
#                 "language": "es",
#                 "license": "http://www.gobiernodecanarias.org/istac/aviso_legal.html",
#                 "modified": "mi\u00e9, 06 mar 2024 06:43:25 GMT+0000",
#                 "publisher": "http://datos.gob.es/recurso/sector-publico/org/Organismo/A05003423",
#                 "theme": "http://datos.gob.es/kos/sector-publico/sector/sector-publico",
#                 "title": [
#                     {
#                         "_value": "Clasificaci\u00f3n de establecimientos de restauraci\u00f3n (ISTAC: CL_CNAE_2009_RESTAURACION)",
#                         "_lang": "es"
#                     }
#                 ],
#                 "type": "http://www.w3.org/ns/dcat#Dataset"
#             },
#             {
#                 "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-de-no-residentes-segun-sexos-grupos-de-edad-y-causas-de-muerte-grandes-grupos-de-cie-10-canarias-por-ano",
#                 "description": [
#                     {
#                         "_value": "En esta tabla se ofrecen datos desde 1999 sobre las defunciones de no residentes seg\u00fan sexos, grupos de edad y causas de muerte (grandes grupos de CIE - 10). La informaci\u00f3n se desagrega territorialmente a nivel de Canarias.",
#                         "_lang": "es"
#                     }
#                 ],
#                 "distribution": [
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-de-no-residentes-segun-sexos-grupos-de-edad-y-causas-de-muerte-grandes-grupos-de-cie-10-canarias-por-ano/resource/4a6fc874-49f1-48ce-8921-556829a64f6b",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000005/1.1.json",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-de-no-residentes-segun-sexos-grupos-de-edad-y-causas-de-muerte-grandes-grupos-de-cie-10-canarias-por-ano/resource/4a6fc874-49f1-48ce-8921-556829a64f6b/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/json"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000005 (JSON)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-de-no-residentes-segun-sexos-grupos-de-edad-y-causas-de-muerte-grandes-grupos-de-cie-10-canarias-por-ano/resource/6633581f-8541-4cda-9661-e8ea2abaa6c5",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000005/1.1.xml",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-de-no-residentes-segun-sexos-grupos-de-edad-y-causas-de-muerte-grandes-grupos-de-cie-10-canarias-por-ano/resource/6633581f-8541-4cda-9661-e8ea2abaa6c5/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/xml"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000005 (XML)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-de-no-residentes-segun-sexos-grupos-de-edad-y-causas-de-muerte-grandes-grupos-de-cie-10-canarias-por-ano/resource/67631765-79e5-44df-a000-d39b9185cf1a",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000005/1.1.tsv",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-de-no-residentes-segun-sexos-grupos-de-edad-y-causas-de-muerte-grandes-grupos-de-cie-10-canarias-por-ano/resource/67631765-79e5-44df-a000-d39b9185cf1a/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "text/tab-separated-values"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000005 (TSV)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-de-no-residentes-segun-sexos-grupos-de-edad-y-causas-de-muerte-grandes-grupos-de-cie-10-canarias-por-ano/resource/80c6cb76-3c58-428f-a0e8-00088aab8a5d",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000005/1.1.xlsx",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-de-no-residentes-segun-sexos-grupos-de-edad-y-causas-de-muerte-grandes-grupos-de-cie-10-canarias-por-ano/resource/80c6cb76-3c58-428f-a0e8-00088aab8a5d/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000005 (XLSX)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-de-no-residentes-segun-sexos-grupos-de-edad-y-causas-de-muerte-grandes-grupos-de-cie-10-canarias-por-ano/resource/9c6c38c2-8745-429b-b6e7-a5147427da4f",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000005/1.1.jsonstat",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-de-no-residentes-segun-sexos-grupos-de-edad-y-causas-de-muerte-grandes-grupos-de-cie-10-canarias-por-ano/resource/9c6c38c2-8745-429b-b6e7-a5147427da4f/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/json"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000005 (JSONSTAT)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-de-no-residentes-segun-sexos-grupos-de-edad-y-causas-de-muerte-grandes-grupos-de-cie-10-canarias-por-ano/resource/f4f7c0c2-9dd9-4b0f-adfc-a51a120dbe78",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000005/1.1.csv",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-de-no-residentes-segun-sexos-grupos-de-edad-y-causas-de-muerte-grandes-grupos-de-cie-10-canarias-por-ano/resource/f4f7c0c2-9dd9-4b0f-adfc-a51a120dbe78/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "text/csv"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000005 (CSV)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     }
#                 ],
#                 "identifier": "https://datos.canarias.es/catalogos/estadisticas/dataset/urn-siemac-org-siemac-metamac-infomodel-statisticalresources-dataset-istac-e30417a_000005",
#                 "issued": "mi\u00e9, 06 mar 2024 08:12:56 GMT+0000",
#                 "keyword": [
#                     {
#                         "_value": "Cubo estad\u00edstico",
#                         "_lang": "es"
#                     }
#                 ],
#                 "language": "es",
#                 "license": "http://www.gobiernodecanarias.org/istac/aviso_legal.html",
#                 "modified": "mi\u00e9, 05 feb 2025 09:49:44 GMT+0000",
#                 "publisher": "http://datos.gob.es/recurso/sector-publico/org/Organismo/A05003423",
#                 "theme": [
#                     "http://datos.gob.es/kos/sector-publico/sector/demografia",
#                     "http://datos.gob.es/kos/sector-publico/sector/legislacion-justicia",
#                     "http://datos.gob.es/kos/sector-publico/sector/salud"
#                 ],
#                 "title": [
#                     {
#                         "_value": "Defunciones de no residentes seg\u00fan sexos, grupos de edad y causas de muerte (grandes grupos de CIE - 10). Canarias por a\u00f1o",
#                         "_lang": "es"
#                     }
#                 ],
#                 "type": "http://www.w3.org/ns/dcat#Dataset"
#             },
#             {
#                 "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-municipios-y-periodos",
#                 "description": [
#                     {
#                         "_value": "En esta tabla se ofrecen datos desde 2010 sobre ahogamientos y sumersiones seg\u00fan sexos. La informaci\u00f3n se desagrega territorialmente a nivel municipios de Canarias.",
#                         "_lang": "es"
#                     }
#                 ],
#                 "distribution": [
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-municipios-y-periodos/resource/68dc5b7b-25b1-43f9-96e3-6b1778618bb7",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000012/1.1.csv",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-municipios-y-periodos/resource/68dc5b7b-25b1-43f9-96e3-6b1778618bb7/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "text/csv"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000012 (CSV)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-municipios-y-periodos/resource/943b77ef-b68a-41bd-9ebc-309ee68de860",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000012/1.1.xml",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-municipios-y-periodos/resource/943b77ef-b68a-41bd-9ebc-309ee68de860/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/xml"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000012 (XML)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-municipios-y-periodos/resource/999fb7b7-2d9e-4179-ab90-dbbb5500af5c",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000012/1.1.tsv",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-municipios-y-periodos/resource/999fb7b7-2d9e-4179-ab90-dbbb5500af5c/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "text/tab-separated-values"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000012 (TSV)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-municipios-y-periodos/resource/a0e36b56-7c11-4b6d-ab89-e659fd0ed24a",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000012/1.1.jsonstat",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-municipios-y-periodos/resource/a0e36b56-7c11-4b6d-ab89-e659fd0ed24a/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/json"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000012 (JSONSTAT)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-municipios-y-periodos/resource/a41d38d3-57cd-4d52-8360-bb2ee7a90cb5",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000012/1.1.xlsx",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-municipios-y-periodos/resource/a41d38d3-57cd-4d52-8360-bb2ee7a90cb5/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000012 (XLSX)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-municipios-y-periodos/resource/ef0f48fc-e566-401b-8d8b-5a837c7081af",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000012/1.1.json",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-municipios-y-periodos/resource/ef0f48fc-e566-401b-8d8b-5a837c7081af/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/json"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000012 (JSON)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     }
#                 ],
#                 "identifier": "https://datos.canarias.es/catalogos/estadisticas/dataset/urn-siemac-org-siemac-metamac-infomodel-statisticalresources-dataset-istac-e30417a_000012",
#                 "issued": "mi\u00e9, 06 mar 2024 08:13:17 GMT+0000",
#                 "keyword": [
#                     {
#                         "_value": "Cubo estad\u00edstico",
#                         "_lang": "es"
#                     }
#                 ],
#                 "language": "es",
#                 "license": "http://www.gobiernodecanarias.org/istac/aviso_legal.html",
#                 "modified": "mi\u00e9, 05 feb 2025 09:49:01 GMT+0000",
#                 "publisher": "http://datos.gob.es/recurso/sector-publico/org/Organismo/A05003423",
#                 "theme": [
#                     "http://datos.gob.es/kos/sector-publico/sector/demografia",
#                     "http://datos.gob.es/kos/sector-publico/sector/legislacion-justicia",
#                     "http://datos.gob.es/kos/sector-publico/sector/salud"
#                 ],
#                 "title": [
#                     {
#                         "_value": "Defunciones por ahogamiento y sumersi\u00f3n accidental inscritas en Canarias seg\u00fan sexos. Municipios y periodos",
#                         "_lang": "es"
#                     }
#                 ],
#                 "type": "http://www.w3.org/ns/dcat#Dataset"
#             },
#             {
#                 "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-y-grupos-de-edad-islas-y-periodos",
#                 "description": [
#                     {
#                         "_value": "En esta tabla se ofrecen datos desde 2010 sobre ahogamientos y sumersiones seg\u00fan sexos y grupos de edad. La informaci\u00f3n se desagrega territorialmente a nivel islas de Canarias.",
#                         "_lang": "es"
#                     }
#                 ],
#                 "distribution": [
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-y-grupos-de-edad-islas-y-periodos/resource/04bf02c9-019d-4073-9c07-bedf2e180d04",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000010/1.1.tsv",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-y-grupos-de-edad-islas-y-periodos/resource/04bf02c9-019d-4073-9c07-bedf2e180d04/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "text/tab-separated-values"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000010 (TSV)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-y-grupos-de-edad-islas-y-periodos/resource/2f22795b-5c7c-458a-93f8-2be4661b4d24",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000010/1.1.csv",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-y-grupos-de-edad-islas-y-periodos/resource/2f22795b-5c7c-458a-93f8-2be4661b4d24/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "text/csv"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000010 (CSV)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-y-grupos-de-edad-islas-y-periodos/resource/32493cdc-7d37-433f-a189-ed6e2b10d9ec",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000010/1.1.xlsx",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-y-grupos-de-edad-islas-y-periodos/resource/32493cdc-7d37-433f-a189-ed6e2b10d9ec/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000010 (XLSX)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-y-grupos-de-edad-islas-y-periodos/resource/43fa0e8e-bc8f-442d-894f-bcd55c3e4905",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000010/1.1.xml",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-y-grupos-de-edad-islas-y-periodos/resource/43fa0e8e-bc8f-442d-894f-bcd55c3e4905/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/xml"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000010 (XML)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-y-grupos-de-edad-islas-y-periodos/resource/795630ab-6be2-46d5-ba8f-c8a57b02a9f5",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000010/1.1.jsonstat",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-y-grupos-de-edad-islas-y-periodos/resource/795630ab-6be2-46d5-ba8f-c8a57b02a9f5/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/json"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000010 (JSONSTAT)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-y-grupos-de-edad-islas-y-periodos/resource/e59cde3e-385c-4e69-88c3-81020e527a97",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000010/1.1.json",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-ahogamiento-y-sumersion-accidental-inscritas-en-canarias-segun-sexos-y-grupos-de-edad-islas-y-periodos/resource/e59cde3e-385c-4e69-88c3-81020e527a97/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/json"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000010 (JSON)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     }
#                 ],
#                 "identifier": "https://datos.canarias.es/catalogos/estadisticas/dataset/urn-siemac-org-siemac-metamac-infomodel-statisticalresources-dataset-istac-e30417a_000010",
#                 "issued": "mi\u00e9, 06 mar 2024 08:13:11 GMT+0000",
#                 "keyword": [
#                     {
#                         "_value": "Cubo estad\u00edstico",
#                         "_lang": "es"
#                     }
#                 ],
#                 "language": "es",
#                 "license": "http://www.gobiernodecanarias.org/istac/aviso_legal.html",
#                 "modified": "mi\u00e9, 05 feb 2025 09:49:14 GMT+0000",
#                 "publisher": "http://datos.gob.es/recurso/sector-publico/org/Organismo/A05003423",
#                 "theme": [
#                     "http://datos.gob.es/kos/sector-publico/sector/demografia",
#                     "http://datos.gob.es/kos/sector-publico/sector/legislacion-justicia",
#                     "http://datos.gob.es/kos/sector-publico/sector/salud"
#                 ],
#                 "title": [
#                     {
#                         "_value": "Defunciones por ahogamiento y sumersi\u00f3n accidental inscritas en Canarias seg\u00fan sexos y grupos de edad. Islas y periodos",
#                         "_lang": "es"
#                     }
#                 ],
#                 "type": "http://www.w3.org/ns/dcat#Dataset"
#             },
#             {
#                 "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-periodo-de-la-defuncion-y-causa-de-muerte-islas-por-ano",
#                 "description": [
#                     {
#                         "_value": "En esta tabla se ofrecen datos desde 2020 sobre la covid-19 seg\u00fan periodos de la defunci\u00f3n. La informaci\u00f3n se desagrega territorialmente a nivel islas de Canarias.",
#                         "_lang": "es"
#                     }
#                 ],
#                 "distribution": [
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-periodo-de-la-defuncion-y-causa-de-muerte-islas-por-ano/resource/235f3389-16d8-40e0-9e9f-55a7f8bae577",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000016/1.1.jsonstat",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-periodo-de-la-defuncion-y-causa-de-muerte-islas-por-ano/resource/235f3389-16d8-40e0-9e9f-55a7f8bae577/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/json"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000016 (JSONSTAT)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-periodo-de-la-defuncion-y-causa-de-muerte-islas-por-ano/resource/26d184d4-fedf-42a5-af17-ad25707cbc2a",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000016/1.1.json",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-periodo-de-la-defuncion-y-causa-de-muerte-islas-por-ano/resource/26d184d4-fedf-42a5-af17-ad25707cbc2a/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/json"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000016 (JSON)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-periodo-de-la-defuncion-y-causa-de-muerte-islas-por-ano/resource/2f04c3ed-4925-4a2c-b6c2-9f3598f1f13c",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000016/1.1.xlsx",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-periodo-de-la-defuncion-y-causa-de-muerte-islas-por-ano/resource/2f04c3ed-4925-4a2c-b6c2-9f3598f1f13c/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000016 (XLSX)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-periodo-de-la-defuncion-y-causa-de-muerte-islas-por-ano/resource/4c854d50-ee3e-498a-b0f4-a9cde8f0aa33",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000016/1.1.tsv",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-periodo-de-la-defuncion-y-causa-de-muerte-islas-por-ano/resource/4c854d50-ee3e-498a-b0f4-a9cde8f0aa33/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "text/tab-separated-values"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000016 (TSV)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-periodo-de-la-defuncion-y-causa-de-muerte-islas-por-ano/resource/8d6d2b3c-9476-441b-a052-49094ebdd776",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000016/1.1.xml",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-periodo-de-la-defuncion-y-causa-de-muerte-islas-por-ano/resource/8d6d2b3c-9476-441b-a052-49094ebdd776/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/xml"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000016 (XML)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-periodo-de-la-defuncion-y-causa-de-muerte-islas-por-ano/resource/9cb1d97e-bb61-4755-9c09-554dac9787d8",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000016/1.1.csv",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-periodo-de-la-defuncion-y-causa-de-muerte-islas-por-ano/resource/9cb1d97e-bb61-4755-9c09-554dac9787d8/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "text/csv"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000016 (CSV)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     }
#                 ],
#                 "identifier": "https://datos.canarias.es/catalogos/estadisticas/dataset/urn-siemac-org-siemac-metamac-infomodel-statisticalresources-dataset-istac-e30417a_000016",
#                 "issued": "mi\u00e9, 06 mar 2024 08:13:30 GMT+0000",
#                 "keyword": [
#                     {
#                         "_value": "Cubo estad\u00edstico",
#                         "_lang": "es"
#                     }
#                 ],
#                 "language": "es",
#                 "license": "http://www.gobiernodecanarias.org/istac/aviso_legal.html",
#                 "modified": "mi\u00e9, 05 feb 2025 09:48:32 GMT+0000",
#                 "publisher": "http://datos.gob.es/recurso/sector-publico/org/Organismo/A05003423",
#                 "theme": [
#                     "http://datos.gob.es/kos/sector-publico/sector/demografia",
#                     "http://datos.gob.es/kos/sector-publico/sector/legislacion-justicia",
#                     "http://datos.gob.es/kos/sector-publico/sector/salud"
#                 ],
#                 "title": [
#                     {
#                         "_value": "Defunciones por covid-19 de residentes en Canarias seg\u00fan periodo de la defunci\u00f3n y causa de muerte. Islas por a\u00f1o",
#                         "_lang": "es"
#                     }
#                 ],
#                 "type": "http://www.w3.org/ns/dcat#Dataset"
#             },
#             {
#                 "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-sexos-y-causa-de-muerte-municipios-y-periodos",
#                 "description": [
#                     {
#                         "_value": "En esta tabla se ofrecen datos desde 2020 sobre la covid-19 seg\u00fan sexos y causa de muerte. La informaci\u00f3n se desagrega territorialmente a nivel municipios de Canarias.",
#                         "_lang": "es"
#                     }
#                 ],
#                 "distribution": [
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-sexos-y-causa-de-muerte-municipios-y-periodos/resource/0a09cfa7-77a6-407d-9adb-03fa09a90bb9",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/E30417A_000014/1.1.json",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-sexos-y-causa-de-muerte-municipios-y-periodos/resource/0a09cfa7-77a6-407d-9adb-03fa09a90bb9/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/json"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:E30417A_000014 (JSON)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-defunciones-por-covid-19-de-residentes-en-canarias-segun-sexos-y-causa-de-muerte-municipios-y-periodos/resource/101fa843-d375-4dd5-811c-e013131c9eac",
# ...
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-arancelarios-y-zonas-economicas-y-geograficas-canarias-y-anos-desde-2000/resource/413e1c59-3ae4-43dc-a4c7-a9f476e75f24/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/xml"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:C00038A_000004 (XML)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-arancelarios-y-zonas-economicas-y-geograficas-canarias-y-anos-desde-2000/resource/59d2b49a-df0c-418c-9294-14a59c0af85d",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00038A_000004/1.3.csv",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-arancelarios-y-zonas-economicas-y-geograficas-canarias-y-anos-desde-2000/resource/59d2b49a-df0c-418c-9294-14a59c0af85d/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "text/csv"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:C00038A_000004 (CSV)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-arancelarios-y-zonas-economicas-y-geograficas-canarias-y-anos-desde-2000/resource/611b1035-1155-4b58-849b-bba18419d4ab",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00038A_000004/1.3.tsv",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-arancelarios-y-zonas-economicas-y-geograficas-canarias-y-anos-desde-2000/resource/611b1035-1155-4b58-849b-bba18419d4ab/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "text/tab-separated-values"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:C00038A_000004 (TSV)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-arancelarios-y-zonas-economicas-y-geograficas-canarias-y-anos-desde-2000/resource/cf9f220f-3988-4484-984a-99021df2c084",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00038A_000004/1.3.xlsx",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-arancelarios-y-zonas-economicas-y-geograficas-canarias-y-anos-desde-2000/resource/cf9f220f-3988-4484-984a-99021df2c084/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:C00038A_000004 (XLSX)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-arancelarios-y-zonas-economicas-y-geograficas-canarias-y-anos-desde-2000/resource/f8269391-5103-4cbc-9c5e-82fe60e33b3e",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00038A_000004/1.3.json",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-arancelarios-y-zonas-economicas-y-geograficas-canarias-y-anos-desde-2000/resource/f8269391-5103-4cbc-9c5e-82fe60e33b3e/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/json"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:C00038A_000004 (JSON)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     }
#                 ],
#                 "identifier": "https://datos.canarias.es/catalogos/estadisticas/dataset/urn-siemac-org-siemac-metamac-infomodel-statisticalresources-dataset-istac-c00038a_000004",
#                 "issued": "lun, 11 mar 2024 11:23:33 GMT+0000",
#                 "keyword": [
#                     {
#                         "_value": "Cubo estad\u00edstico",
#                         "_lang": "es"
#                     }
#                 ],
#                 "language": "es",
#                 "license": "http://www.gobiernodecanarias.org/istac/aviso_legal.html",
#                 "modified": "vie, 21 feb 2025 13:35:13 GMT+0000",
#                 "publisher": "http://datos.gob.es/recurso/sector-publico/org/Organismo/A05003423",
#                 "theme": "http://datos.gob.es/kos/sector-publico/sector/comercio",
#                 "title": [
#                     {
#                         "_value": "Importaciones y exportaciones seg\u00fan cap\u00edtulos arancelarios y zonas econ\u00f3micas y geogr\u00e1ficas. Canarias y a\u00f1os. Desde 2000",
#                         "_lang": "es"
#                     }
#                 ],
#                 "type": "http://www.w3.org/ns/dcat#Dataset"
#             },
#             {
#                 "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-y-partidas-arancelarias-canarias-y-anos-desde-2000",
#                 "description": [
#                     {
#                         "_value": "Peso y valor de las importaciones y exportaciones de bienes seg\u00fan cap\u00edtulos y partidas arancelarias. Canarias y a\u00f1os. Desde 2000",
#                         "_lang": "es"
#                     }
#                 ],
#                 "distribution": [
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-y-partidas-arancelarias-canarias-y-anos-desde-2000/resource/49da1dd5-53e6-44ca-a87a-94e2cd116bdb",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00038A_000010/1.3.csv",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-y-partidas-arancelarias-canarias-y-anos-desde-2000/resource/49da1dd5-53e6-44ca-a87a-94e2cd116bdb/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "text/csv"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:C00038A_000010 (CSV)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-y-partidas-arancelarias-canarias-y-anos-desde-2000/resource/5e5a5f48-0759-4fb7-93d1-806e2163a0b5",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00038A_000010/1.3.xlsx",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-y-partidas-arancelarias-canarias-y-anos-desde-2000/resource/5e5a5f48-0759-4fb7-93d1-806e2163a0b5/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:C00038A_000010 (XLSX)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-y-partidas-arancelarias-canarias-y-anos-desde-2000/resource/62abc628-69b3-415a-8aba-415f332de1af",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00038A_000010/1.3.json",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-y-partidas-arancelarias-canarias-y-anos-desde-2000/resource/62abc628-69b3-415a-8aba-415f332de1af/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/json"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:C00038A_000010 (JSON)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-y-partidas-arancelarias-canarias-y-anos-desde-2000/resource/7d803819-cc44-4677-9a72-84d59e00646e",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00038A_000010/1.3.tsv",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-y-partidas-arancelarias-canarias-y-anos-desde-2000/resource/7d803819-cc44-4677-9a72-84d59e00646e/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "text/tab-separated-values"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:C00038A_000010 (TSV)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-y-partidas-arancelarias-canarias-y-anos-desde-2000/resource/e13be612-a4c3-4dd1-ad00-3e47dd460749",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00038A_000010/1.3.xml",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-y-partidas-arancelarias-canarias-y-anos-desde-2000/resource/e13be612-a4c3-4dd1-ad00-3e47dd460749/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/xml"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:C00038A_000010 (XML)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     },
#                     {
#                         "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-y-partidas-arancelarias-canarias-y-anos-desde-2000/resource/f88889da-fb38-4471-8742-74b6be66a51e",
#                         "accessURL": "https://datos.canarias.es/api/estadisticas/statistical-resources/v1.0/datasets/ISTAC/C00038A_000010/1.3.jsonstat",
#                         "format": {
#                             "_about": "https://datos.gob.es/catalogo/a05003423-importaciones-y-exportaciones-segun-capitulos-y-partidas-arancelarias-canarias-y-anos-desde-2000/resource/f88889da-fb38-4471-8742-74b6be66a51e/format",
#                             "type": "http://purl.org/dc/terms/IMT",
#                             "value": "application/json"
#                         },
#                         "title": [
#                             {
#                                 "_value": "Cubo estad\u00edstico. ISTAC:C00038A_000010 (JSONSTAT)",
#                                 "_lang": "es"
#                             }
#                         ],
#                         "type": "http://www.w3.org/ns/dcat#Distribution"
#                     }
#                 ],
#                 "identifier": "https://datos.canarias.es/catalogos/estadisticas/dataset/urn-siemac-org-siemac-metamac-infomodel-statisticalresources-dataset-istac-c00038a_000010",
#                 "issued": "lun, 11 mar 2024 11:37:41 GMT+0000",
#                 "keyword": [
#                     {
#                         "_value": "Cubo estad\u00edstico",
#                         "_lang": "es"
#                     }
#                 ],
#                 "language": "es",
#                 "license": "http://www.gobiernodecanarias.org/istac/aviso_legal.html",
#                 "modified": "vie, 21 feb 2025 13:35:46 GMT+0000",
#                 "publisher": "http://datos.gob.es/recurso/sector-publico/org/Organismo/A05003423",
#                 "theme": "http://datos.gob.es/kos/sector-publico/sector/comercio",
#                 "title": [
#                     {
#                         "_value": "Importaciones y exportaciones seg\u00fan cap\u00edtulos y partidas arancelarias. Canarias y a\u00f1os. Desde 2000",
#                         "_lang": "es"
#                     }
#                 ],
#                 "type": "http://www.w3.org/ns/dcat#Dataset"
#             }
#         ],
#         "itemsPerPage": 10,
#         "next": "http://datos.gob.es/apidata/catalog/dataset.json?_page=1",
#         "page": 0,
#         "startIndex": 1,
#         "type": [
#             "http://purl.org/linked-data/api/vocab#ListEndpoint",
#             "http://purl.org/linked-data/api/vocab#Page"
#         ]
#     }
# }
